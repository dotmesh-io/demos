# %%
import pandas as pd
import numpy as np
from sklearn.cross_validation import train_test_split
import matplotlib.pyplot as plt
import json

# %matplotlib inline

# %%
print('DOTSCIENCE_INPUTS=["agent1", "agent2"]')
print('DOTSCIENCE_OUTPUTS=["model"]')
print('DOTSCIENCE_LABELS={"model_type": "random_forest"}')
# Out:
# DOTSCIENCE_INPUTS=["agent1", "agent2"]
# DOTSCIENCE_OUTPUTS=["model"]
# DOTSCIENCE_LABELS={"model_type": "random_forest"}

# %% [markdown]
# We are using a housing price dataset sourced from Bay Area Home Sales Database and Zillow. This dataset was based on the homes sold between January 2013 and December 2015.

# %%
inputs = [pd.read_csv('./agent1/bay_area_zillow_agent1.csv'), pd.read_csv('./agent2/bay_area_zillow_agent2.csv')]
df = pd.concat(f for f in inputs)

# %%
# randomise my dataframe rows to remove any ordering in the data
# TODO fix seed to preserve reproducibility
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
df.describe(include = "all")
# Out:
#           Unnamed: 0                    address  \
# count   11330.000000                      11330
# unique           NaN                      10730
# top              NaN  Address: 1300 Eddy Street
# freq             NaN                          5
# mean     9171.729214                        NaN
# std      4921.941074                        NaN
# min         2.000000                        NaN
# 25%      5039.750000                        NaN
# 50%      9198.500000                        NaN
# 75%     13374.750000                        NaN
# max     17632.000000                        NaN
#
#                                                      info     z_address  \
# count                                               11330         11330
# unique                                              11232         10684
# top     San FranciscoSales price: 2800000Sales date: 0...  1300 Eddy St
# freq                                                    3             5
# mean                                                  NaN           NaN
# std                                                   NaN           NaN
# min                                                   NaN           NaN
# 25%                                                   NaN           NaN
# 50%                                                   NaN           NaN
# 75%                                                   NaN           NaN
# max                                                   NaN           NaN
#
#            bathrooms      bedrooms  finishedsqft lastsolddate  lastsoldprice  \
# count   11330.000000  11330.000000  11330.000000        11330   1.133000e+04
# unique           NaN           NaN           NaN          954            NaN
# top              NaN           NaN           NaN   11/08/2013            NaN
# freq             NaN           NaN           NaN           46            NaN
# mean        1.980229      2.614475   1585.420918          NaN   1.263928e+06
# std         1.047358      1.299457    921.978245          NaN   1.042079e+06
# min         0.500000      0.000000      1.000000          NaN   5.350000e+02
# 25%         1.000000      2.000000   1019.000000          NaN   7.292500e+05
# 50%         2.000000      2.000000   1362.000000          NaN   9.900000e+05
# 75%         2.000000      3.000000   1876.000000          NaN   1.450000e+06
# max        14.000000     20.000000  27275.000000          NaN   2.388900e+07
#
#             latitude     longitude neighborhood    totalrooms       usecode  \
# count   11330.000000  11330.000000        11330  11330.000000         11330
# unique           NaN           NaN           71           NaN            10
# top              NaN           NaN      Mission           NaN  SingleFamily
# freq             NaN           NaN          540           NaN          5803
# mean       37.759711   -122.436518          NaN      6.111562           NaN
# std         0.025578      0.030743          NaN     12.125819           NaN
# min        37.708170   -122.510726          NaN      1.000000           NaN
# 25%        37.739286   -122.455157          NaN      4.000000           NaN
# 50%        37.760513   -122.432510          NaN      5.000000           NaN
# 75%        37.781386   -122.413359          NaN      7.000000           NaN
# max        37.806083   -122.381201          NaN   1264.000000           NaN
#
#            yearbuilt     zestimate   zindexvalue       zipcode          zpid
# count   11330.000000  1.133000e+04  1.133000e+04  11330.000000  1.133000e+04
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean     1948.498147  1.565695e+06  1.320205e+06  94116.912004  3.689973e+07
# std        37.911196  1.229417e+06  5.848170e+05      9.400877  7.800741e+07
# min      1860.000000  4.323850e+05  6.881000e+05  94102.000000  1.506329e+07
# 25%      1916.000000  9.052375e+05  9.829000e+05  94110.000000  1.510847e+07
# 50%      1940.000000  1.230758e+06  1.211900e+06  94115.000000  1.515697e+07
# 75%      1986.000000  1.731170e+06  1.480400e+06  94123.000000  5.970040e+07
# max      2016.000000  1.553325e+07  5.333500e+06  94158.000000  2.146999e+09

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'address', 'info', 'z_address', 'bathrooms', 'bedrooms',
#        'finishedsqft', 'lastsolddate', 'lastsoldprice', 'latitude',
#        'longitude', 'neighborhood', 'totalrooms', 'usecode', 'yearbuilt',
#        'zestimate', 'zindexvalue', 'zipcode', 'zpid'],
#       dtype='object')

# %%
# drop unneeded columns
df.drop(df.columns[[0, 1, 2, 3, 11, 13, 14, 15, 16, 17, 18]], axis=1, inplace=True)

# %%
df.describe(include = "all")
# Out:
#            bathrooms      bedrooms  finishedsqft lastsolddate  lastsoldprice  \
# count   11330.000000  11330.000000  11330.000000        11330   1.133000e+04
# unique           NaN           NaN           NaN          954            NaN
# top              NaN           NaN           NaN   11/08/2013            NaN
# freq             NaN           NaN           NaN           46            NaN
# mean        1.980229      2.614475   1585.420918          NaN   1.263928e+06
# std         1.047358      1.299457    921.978245          NaN   1.042079e+06
# min         0.500000      0.000000      1.000000          NaN   5.350000e+02
# 25%         1.000000      2.000000   1019.000000          NaN   7.292500e+05
# 50%         2.000000      2.000000   1362.000000          NaN   9.900000e+05
# 75%         2.000000      3.000000   1876.000000          NaN   1.450000e+06
# max        14.000000     20.000000  27275.000000          NaN   2.388900e+07
#
#             latitude     longitude    totalrooms
# count   11330.000000  11330.000000  11330.000000
# unique           NaN           NaN           NaN
# top              NaN           NaN           NaN
# freq             NaN           NaN           NaN
# mean       37.759711   -122.436518      6.111562
# std         0.025578      0.030743     12.125819
# min        37.708170   -122.510726      1.000000
# 25%        37.739286   -122.455157      4.000000
# 50%        37.760513   -122.432510      5.000000
# 75%        37.781386   -122.413359      7.000000
# max        37.806083   -122.381201   1264.000000

# %%
# check none of our data is null or NaN
df.isnull().any()
# Out:
# bathrooms        False
# bedrooms         False
# finishedsqft     False
# lastsolddate     False
# lastsoldprice    False
# latitude         False
# longitude        False
# totalrooms       False
# dtype: bool

# %%
# check that we have sensible datatypes for our features
df.dtypes
# Out:
# bathrooms        float64
# bedrooms           int64
# finishedsqft       int64
# lastsolddate      object
# lastsoldprice      int64
# latitude         float64
# longitude        float64
# totalrooms         int64
# dtype: object

# %%
# get time data as datetime datatype. convert floats to ints

df['bathrooms'] = df['bathrooms'].astype('int64', copy=False)
df['lastsolddate'] = pd.to_datetime(df['lastsolddate'])

# %%
# datatypes look more consistent now, and dates will be interpreted correctlu

df.dtypes
# Out:
# bathrooms                 int64
# bedrooms                  int64
# finishedsqft              int64
# lastsolddate     datetime64[ns]
# lastsoldprice             int64
# latitude                float64
# longitude               float64
# totalrooms                int64
# dtype: object

# %% [markdown]
# Now let's try a random forest model on some of these features to predict `lastsoldprice`

# %%
X = df[['bathrooms', 'bedrooms', 'finishedsqft', 'totalrooms', 'longitude', 'latitude']]
Y = df['lastsoldprice']

# %%
# Split data into test and training set. Use random_state for reproducibility
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# input a range of parameters to try. We will fit models with every possible combination of these parameters.
param_grid = [
    {'n_estimators': [3, 10, 12, 14], 'max_features': [1,2, 3, 4, 5, 6], 'bootstrap': [False]}
]

rand_forest_regressor = RandomForestRegressor()

# %%
rand_forest_regressor.get_params().keys()
# Out:
# dict_keys(['bootstrap', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'min_impurity_decrease', 'min_impurity_split', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_jobs', 'oob_score', 'random_state', 'verbose', 'warm_start'])

# %%
grid_search = GridSearchCV(rand_forest_regressor, param_grid, cv=5, scoring='neg_mean_squared_error')

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid=[{'n_estimators': [3, 10, 12, 14], 'max_features': [1, 2, 3, 4, 5, 6], 'bootstrap': [False]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_squared_error', verbose=0)

# %%
# These are our runs

array_runs = grid_search.cv_results_

for mean_score, params in zip(array_runs["mean_test_score"], array_runs["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# 615387.3510853354 {'bootstrap': False, 'max_features': 1, 'n_estimators': 3}
# 557446.7902663273 {'bootstrap': False, 'max_features': 1, 'n_estimators': 10}
# 548120.6930112323 {'bootstrap': False, 'max_features': 1, 'n_estimators': 12}
# 546756.5601205274 {'bootstrap': False, 'max_features': 1, 'n_estimators': 14}
# 613313.9693200146 {'bootstrap': False, 'max_features': 2, 'n_estimators': 3}
# 549758.6396466137 {'bootstrap': False, 'max_features': 2, 'n_estimators': 10}
# 550144.3930132751 {'bootstrap': False, 'max_features': 2, 'n_estimators': 12}
# 544421.3201317303 {'bootstrap': False, 'max_features': 2, 'n_estimators': 14}
# 599302.8665763041 {'bootstrap': False, 'max_features': 3, 'n_estimators': 3}
# 552307.3788286528 {'bootstrap': False, 'max_features': 3, 'n_estimators': 10}
# 559854.2793213297 {'bootstrap': False, 'max_features': 3, 'n_estimators': 12}
# 546502.6513734278 {'bootstrap': False, 'max_features': 3, 'n_estimators': 14}
# 620464.4483515944 {'bootstrap': False, 'max_features': 4, 'n_estimators': 3}
# 558974.1515650693 {'bootstrap': False, 'max_features': 4, 'n_estimators': 10}
# 566818.1413838473 {'bootstrap': False, 'max_features': 4, 'n_estimators': 12}
# 558388.0184260312 {'bootstrap': False, 'max_features': 4, 'n_estimators': 14}
# 632777.4245042759 {'bootstrap': False, 'max_features': 5, 'n_estimators': 3}
# 584939.7114731102 {'bootstrap': False, 'max_features': 5, 'n_estimators': 10}
# 592029.7899275236 {'bootstrap': False, 'max_features': 5, 'n_estimators': 12}
# 588343.0066617881 {'bootstrap': False, 'max_features': 5, 'n_estimators': 14}
# 703106.6777502022 {'bootstrap': False, 'max_features': 6, 'n_estimators': 3}
# 701284.48472899 {'bootstrap': False, 'max_features': 6, 'n_estimators': 10}
# 700799.2982320299 {'bootstrap': False, 'max_features': 6, 'n_estimators': 12}
# 700708.4386178087 {'bootstrap': False, 'max_features': 6, 'n_estimators': 14}

# %%
# scikitlearn uses convention of 'higher score is better', so mean squared error is negated. We take square root and negate that to get rmse

for mean_score, params in zip(array_runs["mean_test_score"], array_runs["params"]):
    param_dict = dict((param_key, params[param_key]) for param_key in params)
    print('DOTSCIENCE_PARAMETERS=' + json.dumps(param_dict))
    print('DOTSCIENCE_SUMMARY=' + json.dumps({"rmse": "%.2f" % np.sqrt(-mean_score)}))
# Out:
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 1, "n_estimators": 3}
# DOTSCIENCE_SUMMARY={"rmse": "615387.35"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 1, "n_estimators": 10}
# DOTSCIENCE_SUMMARY={"rmse": "557446.79"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 1, "n_estimators": 12}
# DOTSCIENCE_SUMMARY={"rmse": "548120.69"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 1, "n_estimators": 14}
# DOTSCIENCE_SUMMARY={"rmse": "546756.56"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 2, "n_estimators": 3}
# DOTSCIENCE_SUMMARY={"rmse": "613313.97"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 2, "n_estimators": 10}
# DOTSCIENCE_SUMMARY={"rmse": "549758.64"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 2, "n_estimators": 12}
# DOTSCIENCE_SUMMARY={"rmse": "550144.39"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 2, "n_estimators": 14}
# DOTSCIENCE_SUMMARY={"rmse": "544421.32"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 3, "n_estimators": 3}
# DOTSCIENCE_SUMMARY={"rmse": "599302.87"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 3, "n_estimators": 10}
# DOTSCIENCE_SUMMARY={"rmse": "552307.38"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 3, "n_estimators": 12}
# DOTSCIENCE_SUMMARY={"rmse": "559854.28"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 3, "n_estimators": 14}
# DOTSCIENCE_SUMMARY={"rmse": "546502.65"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 4, "n_estimators": 3}
# DOTSCIENCE_SUMMARY={"rmse": "620464.45"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 4, "n_estimators": 10}
# DOTSCIENCE_SUMMARY={"rmse": "558974.15"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 4, "n_estimators": 12}
# DOTSCIENCE_SUMMARY={"rmse": "566818.14"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 4, "n_estimators": 14}
# DOTSCIENCE_SUMMARY={"rmse": "558388.02"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 5, "n_estimators": 3}
# DOTSCIENCE_SUMMARY={"rmse": "632777.42"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 5, "n_estimators": 10}
# DOTSCIENCE_SUMMARY={"rmse": "584939.71"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 5, "n_estimators": 12}
# DOTSCIENCE_SUMMARY={"rmse": "592029.79"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 5, "n_estimators": 14}
# DOTSCIENCE_SUMMARY={"rmse": "588343.01"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 6, "n_estimators": 3}
# DOTSCIENCE_SUMMARY={"rmse": "703106.68"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 6, "n_estimators": 10}
# DOTSCIENCE_SUMMARY={"rmse": "701284.48"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 6, "n_estimators": 12}
# DOTSCIENCE_SUMMARY={"rmse": "700799.30"}
# DOTSCIENCE_PARAMETERS={"bootstrap": false, "max_features": 6, "n_estimators": 14}
# DOTSCIENCE_SUMMARY={"rmse": "700708.44"}

# %%
for mean_score, params in zip(array_runs["mean_test_score"], array_runs["params"]):
    param_dict = dict((param_key, params[param_key]) for param_key in params)
    ds.params(param_dict)
    ds.summary("rmse", "%.2f" % np.sqrt(-mean_score)
    ds.clear()
